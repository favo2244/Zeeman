# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import sympy as smp
from matplotlib import animation
from matplotlib.animation import PillowWriter
import math 
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
import scipy.constants as cs

# %%
def I_lin(x,y,z):
    theta = np.arctan(z/np.sqrt(x**2+y**2))
    return np.sin(theta)**2

# %%
I_lin(1,1,1)
# Out:
# np.float64(0.3333333333333333)

# %%
def plot(val):
    theta = np.sqrt(np.arcsin(val))
    return theta

# %%
plot(1)
# Out:
# np.float64(1.2533141373155001)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm

# Parameters
theta = np.linspace(0, 2 * np.pi, 500)  # Angle in radians

# Intensity functions for different polarizations
def intensity_pi(theta):
    # π-transition: Intensity proportional to sin^2(theta)
    return np.sin(theta) ** 2

def intensity_sigma(theta):
    # σ+ transition: Intensity proportional to (1 + cos^2(theta)) / 2
    return (1 + np.cos(theta) ** 2) / 2

# Set up polar plots
fig, axs = plt.subplots(1, 3, subplot_kw={'projection': 'polar'}, figsize=(15, 5))

# Plot π-polarization
axs[0].plot(theta, intensity_pi(theta), color='purple')
axs[0].set_title("π Polarization", va='bottom')
axs[0].fill(theta, intensity_pi(theta), color='purple', alpha=0.3)

# Plot σ+ polarization
axs[1].plot(theta, intensity_sigma_plus(theta), color='orange')
axs[1].set_title("σ+ Polarization", va='bottom')
axs[1].fill(theta, intensity_sigma_plus(theta), color='orange', alpha=0.3)

# Plot σ- polarization
axs[2].plot(theta, intensity_sigma_minus(theta), color='blue')
axs[2].set_title("σ- Polarization", va='bottom')
axs[2].fill(theta, intensity_sigma_minus(theta), color='blue', alpha=0.3)

# Show the plots
plt.suptitle("Intensity Profiles for Dipole Radiation")
plt.show()
